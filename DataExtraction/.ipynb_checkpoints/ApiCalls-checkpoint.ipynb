# %%
pip install ipynb
# Out:
# Requirement already satisfied: ipynb in c:\users\isha\anaconda3\lib\site-packages (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nbimporter
# Out:
# Collecting nbimporterNote: you may need to restart the kernel to use updated packages.
#   Downloading nbimporter-0.3.4-py3-none-any.whl (4.9 kB)
# Installing collected packages: nbimporter
# Successfully installed nbimporter-0.3.4

# %%
# from ipynb.fs.full.Twitter import getTwitterData
import nbimporter
import Twitter as Twitter

# %%
queries = [{"name":'bitcoin', "number": 10}, {"name":'cryptography', "number": 10}, {"name":'dogecoin', "number": 10}]
# queries = [{"name":'cryptography', "number": 10}]
twiTwitter.getTwitterData(queries)
# Out:
# https://api.twitter.com/2/tweets/search/recent?query=bitcoin lang:en  -is:retweet&max_results=10&expansions=author_id&tweet.fields=text,author_id,created_at,lang&user.fields=name,username
# 200
# https://api.twitter.com/2/tweets/search/recent?query=cryptography lang:en  -is:retweet&max_results=10&expansions=author_id&tweet.fields=text,author_id,created_at,lang&user.fields=name,username
# 200
# https://api.twitter.com/2/tweets/search/recent?query=dogecoin lang:en  -is:retweet&max_results=10&expansions=author_id&tweet.fields=text,author_id,created_at,lang&user.fields=name,username
# 200
# [['bitcoin',
#   'bitcoin',
#   '#linkedin #twitter #facebook #instagram #bitcoin #socialmedia #pinterest #medium #reddit #deals #gift #gifts #giftideas #shop #shopping #affiliatemarketing #drizly Delivers the #drinks to you #Beer #wine #liquor delivered in under 60 minutes https://t.co/QfG87kM4D9',
#   'Brett Murphy',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   'All these big names are sleeping on @BMC_NFT . Strongest community I know ! 11.1K NFTS with 3.4K owners with floor sitting at .539 ETH.  INSANE !Respect ! #NFTs #bitcoin',
#   'marioo',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   '#makemoneyonline #affiliatemarketing #networkmarketing #digitalmarketing #makemoney #onlineshop   #affiliatemarketing #gift #shopping #gifts #onlineshopping #dogecoin #bitcoin free shipping on purchases over $25 at #Amazon https://t.co/E0egX01ArP',
#   'brettmurphynet',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   '#linkedin #twitter #facebook #instagram #bitcoin #socialmedia #pinterest #dogecoin #deal #deals #gift #gifts #giftideas #shop #shopping #shoppingonline #cooking #homecooking #affiliatemarketing Become a member https://t.co/QpC2YyFQYQ',
#   'brettmurphynet',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   '#tumblr #twitter #facebook #instagram #dogecoin #socialmedia #pinterest #doge #deal #deals #gift #gifts #giftideas #shop #shopping #affiliatemarketing #bitcoin #freeshipping on purchases over $25 at #Amazon https://t.co/E0egX01ArP',
#   'brettmurphynet',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   '@BalloonzNFT Life is full of symbols and mystery and this is one Price 256.8429 Ethereum\nhttps://t.co/NwZ3bDoWK1\n#NFTs #NFTartists #art #Bitcoin #Crypto #OpenSeaNFT #Ethereum #BTC\n#NFT #NFTAirdrop #nftcollector  #collector #ens #nftart  #تداول #عملات_رقمية #ETH #Trader #Game #NFTCommunity',
#   'antique NFT',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   'really, why do people celebrate, when a price goes up for 3 % and cry the shit out themselves, when a price goes down for 1%?\nWhat do you expect? Moon only x thousand baggers?! C‘mon it ain‘t that easy\n#cryptocurrency #Bitcoin #StockMarket #nasdaq #Crypto #TradingView #traders https://t.co/xBt2PUHUnB',
#   'Geasyfit',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   'ETH 2.0 Contract Surpasses 9 Million Ethereum Worth $28 Billion – Technology Bitcoin News https://t.co/zH0A5sTjk5',
#   'RICH',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   "@davidiach What the problem, if a dude can move the market with a relatively small percentage, a relatively small percentage can bring it up. It's the same with bitcoin... or any scarce asset. If people want it, the price will go up. I bought in yesterday and was happy for the dip.",
#   'gm (gm,gm)',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['bitcoin',
#   'bitcoin',
#   '@Kris_HK Buy Pet Planet @petplanetbsc $PP 🏝️🐈\nNFT Ecosystem for pet lovers!\nUnder $1M ⚡ EASY 100X GEM!\nSOLID TEAM💪✨\n\nWeb    : https://t.co/RIcZ3NcCCU\nTG 🌐 : https://t.co/Cn89BPJQan\n🚀🚀🔥🔥🔥🔥🔥🔥🔥\n#PetPlanet #binance #bsc #bitcoin #crypto #NFT #NFTCommunity https://t.co/3yioJOUOzi',
#   'RYZ | GGWP',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   'Brought to you by this commit. https://t.co/U15mMACo59',
#   "Koz 'Intersectional Feminist Spectrum Weeb' Ross",
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   'https://t.co/UOsoTYXbwI Cryptography Training | Part 3 - Encryption Algorithms and\nKeylengths #cybersecurity',
#   'Security News',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   '#Bitcoin was made by people, for the people. \n\n#Bitcoin is a digital currency which operates free of any central control or the oversight of banks or governments! \nInstead it relies on peer-to-peer software and cryptography. \n\nRevolutionary! \n\nGet some❣️👊',
#   'SYDNEY THUNDER',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   "The best defence against the dark arts is capital efficiency. Expelliarmus won't save you from sandwiches, but cryptographically-signed quotes will.\n\n#Hashflow #Defi #cryptography https://t.co/g6B14UwPzX",
#   'Noni',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   "@PhantomMedalli1 @Arthur_0x All of it is sort of esoteric applied math. It's cryptography.",
#   'root',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   '25 Companies Building The Quantum Cryptography &amp; Communications Markets by @QuantumDaily\n\nhttps://t.co/W364A4yqtB #QuantumComputing',
#   'aispirits',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   'Quantum Cryptography: From Key Distribution to Conference Key Agreement (Quan... https://t.co/eLOkCJ5iSA via @amazon',
#   'Organized Mind',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   '@UniqueVietNams @Coinw_exchange @Coinw_exchange gives user an edge over the market with amazing tools, in an all in one so simple platform all experience levels. What specifically are the tools that @Coinw_exchange provides to investors with little knowledge of trading and cryptography in general?',
#   'Md Sahel',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   '@cryptogemmouse @bnb_global @bnb_global gives user an edge over the market with amazing tools, in an all in one so simple platform all experience levels. What specifically are the tools that @bnb_global provides to investors with little knowledge of trading and cryptography in general?',
#   'Md Sahel',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['cryptography',
#   'cryptography',
#   'Digital asset Asmap miner Szabo transaction Nakamoto Schnorr security token node cryptography Monero UTXO. Op return transaction Monero hyperbitcoinization Ethereum node Schnorr moon. UTXO transaction immutable Litecoin moon wallet pseudony',
#   'LoremCrypto',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   'New cruces #Crypto #criptomonedas #PrimeXBT #Uniswap #Polkadot #CardanoADA #dogecoin #Ripple #SOLANA #Chainlink https://t.co/Quwyhh0VLR https://t.co/mUeB9PoGP7 #ADA #DOT #ADAUSDT #DOTUSDT #XRP #XRPUSD #SOL #SOLUSDT #LINK #LINKUSDT #DOGE #DOGEUSDT #cryptopunks #NFT #NFTGiveaway',
#   'Educación Financiera y Criptomonedas',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   '#makemoneyonline #affiliatemarketing #networkmarketing #digitalmarketing #makemoney #onlineshop   #affiliatemarketing #gift #shopping #gifts #onlineshopping #dogecoin #bitcoin free shipping on purchases over $25 at #Amazon https://t.co/E0egX01ArP',
#   'brettmurphynet',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   '#linkedin #twitter #facebook #instagram #bitcoin #socialmedia #pinterest #dogecoin #deal #deals #gift #gifts #giftideas #shop #shopping #shoppingonline #cooking #homecooking #affiliatemarketing Become a member https://t.co/QpC2YyFQYQ',
#   'brettmurphynet',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   '#tumblr #twitter #facebook #instagram #dogecoin #socialmedia #pinterest #doge #deal #deals #gift #gifts #giftideas #shop #shopping #affiliatemarketing #bitcoin #freeshipping on purchases over $25 at #Amazon https://t.co/E0egX01ArP',
#   'brettmurphynet',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   'TheGlobal crypto regulation bill🚩\n\n@dogecoin\n@Shibtoken\n@Bitcoin\n@Shibtoke\n@vladtenev\n@CryptoWhale\n@Shibaworlde\n@VitalikButerin \n@MattWallace888\n@BillyM2k\n@elonmusk\n@ShytoshiKusama \n@jack\n@WhaleStats \n@WatcherGuru \n@CoinMarketCap \n@coingecko https://t.co/KFIQmxvrLI',
#   'Rahul',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   'Bitcoin, ether, dogecoin, other crypto prices today plunge while Cardano surges over\xa014% https://t.co/TsWhgbyLF3',
#   'SmokeafattywithPaddy.NEWS',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   "Isn't that exactly what you want?\n\n #ShibArmy #ShibaSwap $SHIB $LEASH $BONE #Shibtoken #dogecoin #chainlink #crypto #Coinbase \n#Binance #Shiba $LTC $ADA $XLM $TRX $DOT $ATOM $BNB $VET $ONT $GRT $UNI $eth https://t.co/QIAp0fL5au",
#   'Trex',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   'Our "To the Moon" dark roast coffee in sandhills at Nautical Star Coffee in New Bern, NC! Stop by and grab a bag if you\'re in the area 🐕🚀💯\n#Coffee #dogecoin #cryptocurrency #Ethereum #NorthCarolina #SupportLocal https://t.co/7WJ7DuJuJz',
#   'DogecoinCoffee',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   'Surely people will do the same with #dogecoin https://t.co/c8DIDYcWXb',
#   'иғт.newman',
#   'Twitter',
#   'Twitter',
#   'en'],
#  ['dogecoin',
#   'dogecoin',
#   'Staking Is Coming To The Chainlink Network In 2022\n\nhttps://t.co/jRP16E1RE0\n\n#NFTs #Binance\n#crypto #blockchain #dAPPs #smartcontracts #bitcoin #ethereum #Stablecoins\xa0#DeFi #XRP #XDC #XLM #ADA\xa0#DAO #investing #staking #mining #Dogecoin #Coinbase #ALGORAND #SHIB #NFTs #Metaverse',
#   'Crypto',
#   'Twitter',
#   'Twitter',
#   'en']]
